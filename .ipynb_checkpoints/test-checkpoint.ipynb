# %%
import pandas as pd

# %%
df2010 = pd.read_csv('2010data.csv')
df2011 = pd.read_csv('2011data.csv')
print(df2010.head())
print(df2011.tail())
# Out:
#    Duration           Start date             End date  Start station number  \
# 0      1012  2010-09-20 11:27:04  2010-09-20 11:43:56                 31208
# 1        61  2010-09-20 11:41:22  2010-09-20 11:42:23                 31209
# 2      2690  2010-09-20 12:05:37  2010-09-20 12:50:27                 31600
# 3      1406  2010-09-20 12:06:05  2010-09-20 12:29:32                 31600
# 4      1413  2010-09-20 12:10:43  2010-09-20 12:34:17                 31100
#
#                    Start station  End station number  \
# 0       M St & New Jersey Ave SE               31108
# 1                 1st & N St  SE               31209
# 2                  5th & K St NW               31100
# 3                  5th & K St NW               31602
# 4  19th St & Pennsylvania Ave NW               31201
#
#                      End station Bike number Member type
# 0                  4th & M St SW      W00742      Member
# 1                 1st & N St  SE      W00032      Member
# ...

# %%
df_final = df2010.append(df2011)
print(df_final.head())
print(df_final.tail())
# Out:
#    Duration           Start date             End date  Start station number  \
# 0      1012  2010-09-20 11:27:04  2010-09-20 11:43:56                 31208
# 1        61  2010-09-20 11:41:22  2010-09-20 11:42:23                 31209
# 2      2690  2010-09-20 12:05:37  2010-09-20 12:50:27                 31600
# 3      1406  2010-09-20 12:06:05  2010-09-20 12:29:32                 31600
# 4      1413  2010-09-20 12:10:43  2010-09-20 12:34:17                 31100
#
#                    Start station  End station number  \
# 0       M St & New Jersey Ave SE               31108
# 1                 1st & N St  SE               31209
# 2                  5th & K St NW               31100
# 3                  5th & K St NW               31602
# 4  19th St & Pennsylvania Ave NW               31201
#
#                      End station Bike number Member type
# 0                  4th & M St SW      W00742      Member
# 1                 1st & N St  SE      W00032      Member
# ...

# %%
df_final.to_csv('trip-dataset.csv')

# %%
df_trip = pd.read_csv('trip-dataset.csv')

# %%
print(df2010.count())
print(df2011.count())
print(df_trip.count())
# Out:
# Duration                115597
# Start date              115597
# End date                115597
# Start station number    115597
# Start station           115597
# End station number      115597
# End station             115597
# Bike number             115597
# Member type             115597
# dtype: int64
# Duration                1226767
# Start date              1226767
# End date                1226767
# Start station number    1226767
# Start station           1226767
# End station number      1226767
# End station             1226767
# Bike number             1226767
# Member type             1226767
# dtype: int64
# Unnamed: 0              1342364
# Duration                1342364
# Start date              1342364
# End date                1342364
# Start station number    1342364
# Start station           1342364
# End station number      1342364
# End station             1342364
# Bike number             1342364
# Member type             1342364
# dtype: int64

# %%
df_trip.head()
# Out:
#    Unnamed: 0  Duration           Start date             End date  \
# 0           0      1012  2010-09-20 11:27:04  2010-09-20 11:43:56
# 1           1        61  2010-09-20 11:41:22  2010-09-20 11:42:23
# 2           2      2690  2010-09-20 12:05:37  2010-09-20 12:50:27
# 3           3      1406  2010-09-20 12:06:05  2010-09-20 12:29:32
# 4           4      1413  2010-09-20 12:10:43  2010-09-20 12:34:17
#
#    Start station number                  Start station  End station number  \
# 0                 31208       M St & New Jersey Ave SE               31108
# 1                 31209                 1st & N St  SE               31209
# 2                 31600                  5th & K St NW               31100
# 3                 31600                  5th & K St NW               31602
# 4                 31100  19th St & Pennsylvania Ave NW               31201
#
#                      End station Bike number Member type
# 0                  4th & M St SW      W00742      Member
# ...

# %%
df_trip = pd.read_csv('trip-dataset.csv')

# %%
df_trip.rename(columns = {"Unnamed: 0": "Index"},inplace = True)
df_trip.head()
# Out:
#    Index  Duration           Start date             End date  \
# 0      0      1012  2010-09-20 11:27:04  2010-09-20 11:43:56
# 1      1        61  2010-09-20 11:41:22  2010-09-20 11:42:23
# 2      2      2690  2010-09-20 12:05:37  2010-09-20 12:50:27
# 3      3      1406  2010-09-20 12:06:05  2010-09-20 12:29:32
# 4      4      1413  2010-09-20 12:10:43  2010-09-20 12:34:17
#
#    Start station number                  Start station  End station number  \
# 0                 31208       M St & New Jersey Ave SE               31108
# 1                 31209                 1st & N St  SE               31209
# 2                 31600                  5th & K St NW               31100
# 3                 31600                  5th & K St NW               31602
# 4                 31100  19th St & Pennsylvania Ave NW               31201
#
#                      End station Bike number Member type
# 0                  4th & M St SW      W00742      Member
# ...

# %%
df_trip.set_index('Index',inplace = True)

# %%
df_trip.tail()
# Out:
#          Duration           Start date             End date  \
# Index
# 1226762       300  2011-12-31 23:41:19  2011-12-31 23:46:20
# 1226763       387  2011-12-31 23:46:43  2011-12-31 23:53:10
# 1226764       261  2011-12-31 23:47:27  2011-12-31 23:51:49
# 1226765      2060  2011-12-31 23:55:12  2012-01-01 00:29:33
# 1226766       468  2011-12-31 23:55:56  2012-01-01 00:03:45
#
#          Start station number                      Start station  \
# Index
# 1226762                 31201                     15th & P St NW
# 1226763                 31223  Convention Center / 7th & M St NW
# 1226764                 31107            Lamont & Mt Pleasant NW
# 1226765                 31205                     21st & I St NW
# 1226766                 31221                     18th & M St NW
#
#          End station number                End station Bike number Member type
# Index
# 1226762               31214      17th & Corcoran St NW      W01459      Member
# ...

# %%
df_trip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1342364 entries, 0 to 1226766
# Data columns (total 9 columns):
# Duration                1342364 non-null int64
# Start date              1342364 non-null object
# End date                1342364 non-null object
# Start station number    1342364 non-null int64
# Start station           1342364 non-null object
# End station number      1342364 non-null int64
# End station             1342364 non-null object
# Bike number             1342364 non-null object
# Member type             1342364 non-null object
# dtypes: int64(3), object(6)
# memory usage: 102.4+ MB

# %%
df_trip['Start date'] = df_trip['Start date'].astype('datetime64[ns]')
df_trip['End date'] = df_trip['End date'].astype('datetime64[ns]')
df_trip['Start station'] = df_trip['Start station'].astype(str)
df_trip['End station'] = df_trip['End station'].astype(str)
df_trip['Bike number'] = df_trip['Bike number'].astype(str)
df_trip['Member type'] = df_trip['Member type'].astype(str)

# %%
df_trip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1342364 entries, 0 to 1226766
# Data columns (total 9 columns):
# Duration                1342364 non-null int64
# Start date              1342364 non-null datetime64[ns]
# End date                1342364 non-null datetime64[ns]
# Start station number    1342364 non-null int64
# Start station           1342364 non-null object
# End station number      1342364 non-null int64
# End station             1342364 non-null object
# Bike number             1342364 non-null object
# Member type             1342364 non-null object
# dtypes: datetime64[ns](2), int64(3), object(4)
# memory usage: 102.4+ MB

# %%
df_trip.tail()
# Out:
#          Duration          Start date            End date  \
# Index
# 1226762       300 2011-12-31 23:41:19 2011-12-31 23:46:20
# 1226763       387 2011-12-31 23:46:43 2011-12-31 23:53:10
# 1226764       261 2011-12-31 23:47:27 2011-12-31 23:51:49
# 1226765      2060 2011-12-31 23:55:12 2012-01-01 00:29:33
# 1226766       468 2011-12-31 23:55:56 2012-01-01 00:03:45
#
#          Start station number                      Start station  \
# Index
# 1226762                 31201                     15th & P St NW
# 1226763                 31223  Convention Center / 7th & M St NW
# 1226764                 31107            Lamont & Mt Pleasant NW
# 1226765                 31205                     21st & I St NW
# 1226766                 31221                     18th & M St NW
#
#          End station number                End station Bike number Member type
# Index
# 1226762               31214      17th & Corcoran St NW      W01459      Member
# ...

# %%
hist = df_trip.hist()

# %%
df_trip.isna().sum()
# Out:
# Duration                0
# Start date              0
# End date                0
# Start station number    0
# Start station           0
# End station number      0
# End station             0
# Bike number             0
# Member type             0
# dtype: int64

# %%
df_trip['Member type'] = df_trip['Member type'].astype('category')

# %%
df = df_trip[['Duration','Start date','End date','Start station number','End station number','Bike number','Member type']]
df.head()
# Out:
#        Duration          Start date            End date  Start station number  \
# Index
# 0          1012 2010-09-20 11:27:04 2010-09-20 11:43:56                 31208
# 1            61 2010-09-20 11:41:22 2010-09-20 11:42:23                 31209
# 2          2690 2010-09-20 12:05:37 2010-09-20 12:50:27                 31600
# 3          1406 2010-09-20 12:06:05 2010-09-20 12:29:32                 31600
# 4          1413 2010-09-20 12:10:43 2010-09-20 12:34:17                 31100
#
#        End station number Bike number Member type
# Index
# 0                   31108      W00742      Member
# 1                   31209      W00032      Member
# 2                   31100      W00993      Member
# 3                   31602      W00344      Member
# 4                   31201      W00883      Member

# %%
df['Member type'].value_counts()
# Out:
# Member     1071400
# Casual      270950
# Unknown         14
# Name: Member type, dtype: int64

# %%
df['Bike number'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3F\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Bike number'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-240-dc61e88e4340> in <module>()
# ----> 1 df['Bike number'].value_counts()
#
# ...

# %%
df.drop(['Bike number'],axis = 1,inplace=True)
# Out:
# C:\Users\Mohit-PC\Anaconda3F\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
df.head()
# Out:
#        Duration          Start date            End date  Start station number  \
# Index
# 0          1012 2010-09-20 11:27:04 2010-09-20 11:43:56                 31208
# 1            61 2010-09-20 11:41:22 2010-09-20 11:42:23                 31209
# 2          2690 2010-09-20 12:05:37 2010-09-20 12:50:27                 31600
# 3          1406 2010-09-20 12:06:05 2010-09-20 12:29:32                 31600
# 4          1413 2010-09-20 12:10:43 2010-09-20 12:34:17                 31100
#
#        End station number Member type
# Index
# 0                   31108      Member
# 1                   31209      Member
# 2                   31100      Member
# 3                   31602      Member
# 4                   31201      Member

# %%
df['syear'] = df['Start date'].dt.year 
df['smonth'] = df['Start date'].dt.month 
df['sday'] = df['Start date'].dt.day 
df['shour'] = df['Start date'].dt.hour 
df['sminute'] = df['Start date'].dt.minute
# Out:
# C:\Users\Mohit-PC\Anaconda3F\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Mohit-PC\Anaconda3F\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df.head()
# Out:
#        Duration          Start date            End date  Start station number  \
# Index
# 0          1012 2010-09-20 11:27:04 2010-09-20 11:43:56                 31208
# 1            61 2010-09-20 11:41:22 2010-09-20 11:42:23                 31209
# 2          2690 2010-09-20 12:05:37 2010-09-20 12:50:27                 31600
# 3          1406 2010-09-20 12:06:05 2010-09-20 12:29:32                 31600
# 4          1413 2010-09-20 12:10:43 2010-09-20 12:34:17                 31100
#
#        End station number Member type  syear  smonth  sday  shour  sminute
# Index
# 0                   31108      Member   2010       9    20     11       27
# 1                   31209      Member   2010       9    20     11       41
# 2                   31100      Member   2010       9    20     12        5
# 3                   31602      Member   2010       9    20     12        6
# 4                   31201      Member   2010       9    20     12       10

# %%
df['eyear'] = df['End date'].dt.year 
df['emonth'] = df['End date'].dt.month 
df['eday'] = df['End date'].dt.day 
df['ehour'] = df['End date'].dt.hour 
df['eminute'] = df['End date'].dt.minute

# %%
df.head()
# Out:
#        Duration          Start date            End date  Start station number  \
# Index
# 0          1012 2010-09-20 11:27:04 2010-09-20 11:43:56                 31208
# 1            61 2010-09-20 11:41:22 2010-09-20 11:42:23                 31209
# 2          2690 2010-09-20 12:05:37 2010-09-20 12:50:27                 31600
# 3          1406 2010-09-20 12:06:05 2010-09-20 12:29:32                 31600
# 4          1413 2010-09-20 12:10:43 2010-09-20 12:34:17                 31100
#
#        End station number Member type  syear  smonth  sday  shour  sminute  \
# Index
# 0                   31108      Member   2010       9    20     11       27
# 1                   31209      Member   2010       9    20     11       41
# 2                   31100      Member   2010       9    20     12        5
# 3                   31602      Member   2010       9    20     12        6
# 4                   31201      Member   2010       9    20     12       10
#
# ...

# %%
df.drop(['Start date','End date'],axis = 1,inplace=True)

# %%
df.head()
# Out:
#        Duration  Start station number  End station number Member type  syear  \
# Index
# 0          1012                 31208               31108      Member   2010
# 1            61                 31209               31209      Member   2010
# 2          2690                 31600               31100      Member   2010
# 3          1406                 31600               31602      Member   2010
# 4          1413                 31100               31201      Member   2010
#
#        smonth  sday  shour  sminute  eyear  emonth  eday  ehour  eminute
# Index
# 0           9    20     11       27   2010       9    20     11       43
# 1           9    20     11       41   2010       9    20     11       42
# 2           9    20     12        5   2010       9    20     12       50
# 3           9    20     12        6   2010       9    20     12       29
# 4           9    20     12       10   2010       9    20     12       34

# %%
df = df[['Duration','syear','smonth','sday','shour','sminute','eyear','emonth','eday','ehour','eminute','Start station number','End station number','Member type']]

# %%
df.head()
# Out:
#        Duration  syear  smonth  sday  shour  sminute  eyear  emonth  eday  \
# Index
# 0          1012   2010       9    20     11       27   2010       9    20
# 1            61   2010       9    20     11       41   2010       9    20
# 2          2690   2010       9    20     12        5   2010       9    20
# 3          1406   2010       9    20     12        6   2010       9    20
# 4          1413   2010       9    20     12       10   2010       9    20
#
#        ehour  eminute  Start station number  End station number Member type
# Index
# 0         11       43                 31208               31108      Member
# 1         11       42                 31209               31209      Member
# 2         12       50                 31600               31100      Member
# 3         12       29                 31600               31602      Member
# 4         12       34                 31100               31201      Member

# %%
from sklearn.model_selection import train_test_split
X = df.drop('Member type', axis=1)
y = df['Member type']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn import tree

model = tree.DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
y_predict = model.predict(X_test)

from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_predict)
# Out:
# 0.8134395737668769

# %%
from sklearn.metrics import confusion_matrix

pd.DataFrame(
    confusion_matrix(y_test, y_predict),
    columns=['Predicted Member', 'Predicted Casual','Predicted Unknown'],
    index=['True Member', 'True Casual','True Unknown']
)
# Out:
#               Predicted Member  Predicted Casual  Predicted Unknown
# True Member              39392             28226                  0
# True Casual              34376            233591                  4
# True Unknown                 0                 2                  0

# %%
df_trip.head()
# Out:
#        Duration          Start date            End date  Start station number  \
# Index
# 0          1012 2010-09-20 11:27:04 2010-09-20 11:43:56                 31208
# 1            61 2010-09-20 11:41:22 2010-09-20 11:42:23                 31209
# 2          2690 2010-09-20 12:05:37 2010-09-20 12:50:27                 31600
# 3          1406 2010-09-20 12:06:05 2010-09-20 12:29:32                 31600
# 4          1413 2010-09-20 12:10:43 2010-09-20 12:34:17                 31100
#
#                        Start station  End station number  \
# Index
# 0           M St & New Jersey Ave SE               31108
# 1                     1st & N St  SE               31209
# 2                      5th & K St NW               31100
# 3                      5th & K St NW               31602
# 4      19th St & Pennsylvania Ave NW               31201
#
#                          End station Bike number Member type
# Index
# 0                      4th & M St SW      W00742      Member
# ...

# %%
df1 = df_trip.drop(['Start station','End station','Bike number'],axis=1)
df1['Start date'] = df1['Start date'].apply(lambda x: x.toordinal())

# %%
df1['End date'] = df1['End date'].apply(lambda x: x.toordinal())
df1.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-241-21af478558ec> in <module>()
# ----> 1 df1['End date'] = df1['End date'].apply(lambda x: x.toordinal())
#       2 df1.head()
#
# ~\Anaconda3F\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-241-21af478558ec> in <lambda>(x)
# ----> 1 df1['End date'] = df1['End date'].apply(lambda x: x.toordinal())
#       2 df1.head()
#
# AttributeError: 'int' object has no attribute 'toordinal'

# %%
X = df1.drop('Member type', axis=1)
y = df1['Member type']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
model = tree.DecisionTreeClassifier()
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
print('Accuracy: ',accuracy_score(y_test, y_predict))
pd.DataFrame(
    confusion_matrix(y_test, y_predict),
    columns=['Predicted Casual', 'Predicted Member','Predicted Unknown'],
    index=['True Casual', 'True Member','True Unknown']
)
# Out:
# Accuracy:  0.8145689246731885
#               Predicted Casual  Predicted Member  Predicted Unknown
# True Casual              38492             29125                  1
# True Member              33098            234870                  3
# True Unknown                 0                 2                  0

# %%
df1['Member type'].value_counts()
# Out:
# Member     1071400
# Casual      270950
# Unknown         14
# Name: Member type, dtype: int64

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
print('Accuracy: ',accuracy_score(y_test, y_predict))
pd.DataFrame(
    confusion_matrix(y_test, y_predict),
    columns=['Predicted Casual', 'Predicted Member','Predicted Unknown'],
    index=['True Casual', 'True Member','True Unknown']
)
# Out:
# C:\Users\Mohit-PC\Anaconda3F\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# Accuracy:  0.8664117929265087
#               Predicted Casual  Predicted Member  Predicted Unknown
# True Casual              41249             26369                  0
# True Member              18459            249511                  1
# True Unknown                 0                 2                  0

# %%
from sklearn.model_selection import train_test_split
X = df.drop('Member type', axis=1)
y = df['Member type']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
df.head()
# Out:
#        Duration  syear  smonth  sday  shour  sminute  eyear  emonth  eday  \
# Index
# 0          1012   2010       9    20     11       27   2010       9    20
# 1            61   2010       9    20     11       41   2010       9    20
# 2          2690   2010       9    20     12        5   2010       9    20
# 3          1406   2010       9    20     12        6   2010       9    20
# 4          1413   2010       9    20     12       10   2010       9    20
#
#        ehour  eminute  Start station number  End station number Member type
# Index
# 0         11       43                 31208               31108      Member
# 1         11       42                 31209               31209      Member
# 2         12       50                 31600               31100      Member
# 3         12       29                 31600               31602      Member
# 4         12       34                 31100               31201      Member

# %%
model = ExtraTreesClassifier()
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
print('Accuracy: ',accuracy_score(y_test, y_predict))
pd.DataFrame(
    confusion_matrix(y_test, y_predict),
    columns=['Predicted Casual', 'Predicted Member','Predicted Unknown'],
    index=['True Casual', 'True Member','True Unknown']
)
# Out:
# Accuracy:  0.8778483332389725
#               Predicted Casual  Predicted Member  Predicted Unknown
# True Casual              41015             26603                  0
# True Member              14388            253583                  0
# True Unknown                 0                 2                  0

# %%
df_trip.head(1)
# Out:
#        Duration          Start date            End date  Start station number  \
# Index
# 0          1012 2010-09-20 11:27:04 2010-09-20 11:43:56                 31208
#
#                   Start station  End station number    End station  \
# Index
# 0      M St & New Jersey Ave SE               31108  4th & M St SW
#
#       Bike number Member type
# Index
# 0          W00742      Member

# %%
from sklearn.ensemble import RandomForestClassifier
model =  RandomForestClassifier()
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
print('Accuracy: ',accuracy_score(y_test, y_predict))
pd.DataFrame(
    confusion_matrix(y_test, y_predict),
    columns=['Predicted Casual', 'Predicted Member','Predicted Unknown'],
    index=['True Casual', 'True Member','True Unknown']
)
# Out:
# Accuracy:  0.8765282740001966
#               Predicted Casual  Predicted Member  Predicted Unknown
# True Casual              40225             27393                  0
# True Member              14041            253930                  0
# True Unknown                 0                 2                  0

# %%
X = df1.drop('Member type', axis=1)
y = df1['Member type']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
df1.head()
# Out:
#        Duration  Start date  End date  Start station number  \
# Index
# 0          1012      734035    734035                 31208
# 1            61      734035    734035                 31209
# 2          2690      734035    734035                 31600
# 3          1406      734035    734035                 31600
# 4          1413      734035    734035                 31100
#
#        End station number Member type
# Index
# 0                   31108      Member
# 1                   31209      Member
# 2                   31100      Member
# 3                   31602      Member
# 4                   31201      Member

# %%
from sklearn.ensemble import RandomForestClassifier
model =  RandomForestClassifier()
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
print('Accuracy: ',accuracy_score(y_test, y_predict))
pd.DataFrame(
    confusion_matrix(y_test, y_predict),
    columns=['Predicted Casual', 'Predicted Member','Predicted Unknown'],
    index=['True Casual', 'True Member','True Unknown']
)
# Out:
# Accuracy:  0.866855785763027
#               Predicted Casual  Predicted Member  Predicted Unknown
# True Casual              39496             28122                  0
# True Member              16558            251413                  0
# True Unknown                 0                 2                  0

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(X, y) 
y_predict = neigh.predict(X_test)
print('Accuracy: ',accuracy_score(y_test, y_predict))
pd.DataFrame(
    confusion_matrix(y_test, y_predict),
    columns=['Predicted Casual', 'Predicted Member','Predicted Unknown'],
    index=['True Casual', 'True Member','True Unknown']
)
# Out:
# Accuracy:  0.8986623598368252
#               Predicted Casual  Predicted Member  Predicted Unknown
# True Casual              43064             24554                  0
# True Member               9452            258519                  0
# True Unknown                 0                 2                  0

# %%
X = df.drop('Member type', axis=1)
y = df['Member type']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(X, y) 
y_predict = neigh.predict(X_test)
print('Accuracy: ',accuracy_score(y_test, y_predict))
pd.DataFrame(
    confusion_matrix(y_test, y_predict),
    columns=['Predicted Casual', 'Predicted Member','Predicted Unknown'],
    index=['True Casual', 'True Member','True Unknown']
)
# Out:
# Accuracy:  0.8989990792363323
#               Predicted Casual  Predicted Member  Predicted Unknown
# True Casual              43193             24425                  0
# True Member               9468            258503                  0
# True Unknown                 0                 2                  0

# %%
import matplotlib
boxplot = df1.boxplot(grid=False, rot=45, fontsize=15)

# %%
from sklearn.naive_bayes import GaussianNB

#Create a Gaussian Classifier
model = GaussianNB()
model.fit(X,y)
# Out:
# GaussianNB(priors=None)

# %%
y_predict = model.predict(X_test)
print('Accuracy: ',accuracy_score(y_test, y_predict))
pd.DataFrame(
    confusion_matrix(y_test, y_predict),
    columns=['Predicted Casual', 'Predicted Member','Predicted Unknown'],
    index=['True Casual', 'True Member','True Unknown']
)
# Out:
# Accuracy:  0.8087523205330298
#               Predicted Casual  Predicted Member  Predicted Unknown
# True Casual              14449             51696               1473
# True Member               1530            256959               9482
# True Unknown                 0                 0                  2

# %%
X = df1.drop('Member type', axis=1)
y = df1['Member type']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
model = GaussianNB()
model.fit(X,y)
y_predict = model.predict(X_test)
print('Accuracy: ',accuracy_score(y_test, y_predict))
pd.DataFrame(
    confusion_matrix(y_test, y_predict),
    columns=['Predicted Casual', 'Predicted Member','Predicted Unknown'],
    index=['True Casual', 'True Member','True Unknown']
)
# Out:
# Accuracy:  0.8360444707992765
#               Predicted Casual  Predicted Member  Predicted Unknown
# True Casual              14070             53548                  0
# True Member               1472            266499                  0
# True Unknown                 0                 2                  0

# %%
df.head()
# Out:
#        Duration  syear  smonth  sday  shour  sminute  eyear  emonth  eday  \
# Index
# 0          1012   2010       9    20     11       27   2010       9    20
# 1            61   2010       9    20     11       41   2010       9    20
# 2          2690   2010       9    20     12        5   2010       9    20
# 3          1406   2010       9    20     12        6   2010       9    20
# 4          1413   2010       9    20     12       10   2010       9    20
#
#        ehour  eminute  Start station number  End station number Member type
# Index
# 0         11       43                 31208               31108      Member
# 1         11       42                 31209               31209      Member
# 2         12       50                 31600               31100      Member
# 3         12       29                 31600               31602      Member
# 4         12       34                 31100               31201      Member

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df2 = scaler.fit_transform(df.drop(['Member type'],axis = 1))

# %%
df2.head()
# Out:
#          0         1         2        3         4         5        6   \
# 0 -0.069157 -3.257675  0.509906  0.48374 -0.629379 -0.144881 -3.25766
# 1 -0.447090 -3.257675  0.509906  0.48374 -0.629379  0.665794 -3.25766
# 2  0.597691 -3.257675  0.509906  0.48374 -0.431418 -1.418798 -3.25766
# 3  0.087421 -3.257675  0.509906  0.48374 -0.431418 -1.360892 -3.25766
# 4  0.090203 -3.257675  0.509906  0.48374 -0.431418 -1.129271 -3.25766
#
#          7         8         9         10        11        12
# 0  0.509873  0.483665 -0.659938  0.768111 -0.401023 -0.930638
# 1  0.509873  0.483665 -0.659938  0.710538 -0.395840 -0.404690
# 2  0.509873  0.483665 -0.464609  1.171124  1.630617 -0.972297
# 3  0.509873  0.483665 -0.464609 -0.037914  1.630617  1.641819
# 4  0.509873  0.483665 -0.464609  0.249952 -0.960760 -0.446350

# %%
df2.insert(13, "Member type",list(df['Member type']), True)

# %%
df2.head()
# Out:
#           0         1         2        3         4         5        6  \
# 0 -0.069157 -3.257675  0.509906  0.48374 -0.629379 -0.144881 -3.25766
# 1 -0.447090 -3.257675  0.509906  0.48374 -0.629379  0.665794 -3.25766
# 2  0.597691 -3.257675  0.509906  0.48374 -0.431418 -1.418798 -3.25766
# 3  0.087421 -3.257675  0.509906  0.48374 -0.431418 -1.360892 -3.25766
# 4  0.090203 -3.257675  0.509906  0.48374 -0.431418 -1.129271 -3.25766
#
#           7         8         9        10        11        12 Member type
# 0  0.509873  0.483665 -0.659938  0.768111 -0.401023 -0.930638      Member
# 1  0.509873  0.483665 -0.659938  0.710538 -0.395840 -0.404690      Member
# 2  0.509873  0.483665 -0.464609  1.171124  1.630617 -0.972297      Member
# 3  0.509873  0.483665 -0.464609 -0.037914  1.630617  1.641819      Member
# 4  0.509873  0.483665 -0.464609  0.249952 -0.960760 -0.446350      Member

# %%
#All models

# %%
X = df2.drop('Member type', axis=1)
y = df2['Member type']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
model = GaussianNB()
model.fit(X,y)
y_predict = model.predict(X_test)
print('Accuracy: ',accuracy_score(y_test, y_predict))
pd.DataFrame(
    confusion_matrix(y_test, y_predict),
    columns=['Predicted Casual', 'Predicted Member','Predicted Unknown'],
    index=['True Casual', 'True Member','True Unknown']
)
# Out:
# Accuracy:  0.7984451311268776
#               Predicted Casual  Predicted Member  Predicted Unknown
# True Casual              14454             51067               2097
# True Member               1529            253495              12947
# True Unknown                 0                 0                  2

# %%
model = tree.DecisionTreeClassifier()
model.fit(X,y)
y_predict = model.predict(X_test)
print('Accuracy: ',accuracy_score(y_test, y_predict))
pd.DataFrame(
    confusion_matrix(y_test, y_predict),
    columns=['Predicted Casual', 'Predicted Member','Predicted Unknown'],
    index=['True Casual', 'True Member','True Unknown']
)
# Out:
# Accuracy:  0.9999255045576312
#               Predicted Casual  Predicted Member  Predicted Unknown
# True Casual              67618                 0                  0
# True Member                 25            267946                  0
# True Unknown                 0                 0                  2

# %%
model = ExtraTreesClassifier()
model.fit(X,y)
y_predict = model.predict(X_test)
print('Accuracy: ',accuracy_score(y_test, y_predict))
pd.DataFrame(
    confusion_matrix(y_test, y_predict),
    columns=['Predicted Casual', 'Predicted Member','Predicted Unknown'],
    index=['True Casual', 'True Member','True Unknown']
)
# Out:
# Accuracy:  0.9999255045576312
#               Predicted Casual  Predicted Member  Predicted Unknown
# True Casual              67618                 0                  0
# True Member                 25            267946                  0
# True Unknown                 0                 0                  2

# %%
X = df2.drop('Member type', axis=1)
y = df2['Member type']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
model = RandomForestClassifier()
model.fit(X,y)
y_predict = model.predict(X_test)
print('Accuracy: ',accuracy_score(y_test, y_predict))
pd.DataFrame(
    confusion_matrix(y_test, y_predict),
    columns=['Predicted Casual', 'Predicted Member','Predicted Unknown'],
    index=['True Casual', 'True Member','True Unknown']
)
# Out:
# Accuracy:  0.9938079388303024
#               Predicted Casual  Predicted Member  Predicted Unknown
# True Casual              66305              1313                  0
# True Member                765            267206                  0
# True Unknown                 0                 0                  2

# %%
model = GaussianNB()
model.fit(X,y)
y_predict = model.predict(X_test)
print('Accuracy: ',accuracy_score(y_test, y_predict))
pd.DataFrame(
    confusion_matrix(y_test, y_predict),
    columns=['Predicted Casual', 'Predicted Member','Predicted Unknown'],
    index=['True Casual', 'True Member','True Unknown']
)
# Out:
# Accuracy:  0.7984451311268776
#               Predicted Casual  Predicted Member  Predicted Unknown
# True Casual              14454             51067               2097
# True Member               1529            253495              12947
# True Unknown                 0                 0                  2

# %%
df_2014 = pd.read_csv('2014Q1.csv')
df_2014.head()
# Out:
#    Duration           Start date             End date  Start station number  \
# 0      1716  2014-01-01 00:06:03  2014-01-01 00:34:40                 31102
# 1       154  2014-01-01 00:11:09  2014-01-01 00:13:43                 31602
# 2       318  2014-01-01 00:12:19  2014-01-01 00:17:38                 31223
# 3       480  2014-01-01 00:14:02  2014-01-01 00:22:02                 31203
# 4       345  2014-01-01 00:15:33  2014-01-01 00:21:18                 31241
#
#                        Start station  End station number  \
# 0                11th & Kenyon St NW               31632
# 1            Park Rd & Holmead Pl NW               31107
# 2  Convention Center / 7th & M St NW               31509
# 3         14th & Rhode Island Ave NW               31109
# 4                      Thomas Circle               31600
#
#                 End station Bike number Member type
# 0            15th & F St NE      W01363      Member
# 1   Lamont & Mt Pleasant NW      W01433      Member
# ...

# %%
df_2014['Member type'] = df_2014['Member type'].astype('category')
df_2014['Start date'] = df_2014['Start date'].astype('datetime64[ns]')
df_2014['End date'] = df_2014['End date'].astype('datetime64[ns]')
df_2014['Start station'] = df_2014['Start station'].astype(str)
df_2014['End station'] = df_2014['End station'].astype(str)
df_2014['Bike number'] = df_2014['Bike number'].astype(str)
df_2014.drop(['Bike number'],axis = 1,inplace=True)
df_2014['syear'] = df_2014['Start date'].dt.year 
df_2014['smonth'] = df_2014['Start date'].dt.month 
df_2014['sday'] = df_2014['Start date'].dt.day 
df_2014['shour'] = df_2014['Start date'].dt.hour 
df_2014['sminute'] = df_2014['Start date'].dt.minute 
df_2014['eyear'] = df_2014['End date'].dt.year 
df_2014['emonth'] = df_2014['End date'].dt.month 
df_2014['eday'] = df_2014['End date'].dt.day 
df_2014['ehour'] = df_2014['End date'].dt.hour 
df_2014['eminute'] = df_2014['End date'].dt.minute 
df_2014.drop(['Start date','End date'],axis = 1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3F\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Start date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-200-884a51cf394d> in <module>()
# ...

# %%
df_2014.head()
df_2014.drop(['Start station','End station'],axis = 1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-203-63e716e48bc7> in <module>()
#       1 df_2014.head()
# ----> 2 df_2014.drop(['Start station','End station'],axis = 1,inplace=True)
#       3 df_2014.head()
#
# ~\Anaconda3F\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3F\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
df_2014.head()
# Out:
#    Duration  Start station number  End station number Member type  syear  \
# 0      1716                 31102               31632      Member   2014
# 1       154                 31602               31107      Member   2014
# 2       318                 31223               31509      Member   2014
# 3       480                 31203               31109      Member   2014
# 4       345                 31241               31600      Member   2014
#
#    smonth  sday  shour  sminute  eyear  emonth  eday  ehour  eminute
# 0       1     1      0        6   2014       1     1      0       34
# 1       1     1      0       11   2014       1     1      0       13
# 2       1     1      0       12   2014       1     1      0       17
# 3       1     1      0       14   2014       1     1      0       22
# 4       1     1      0       15   2014       1     1      0       21

# %%
model
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
X = df_2014.drop(['Member type'],axis = 1)
y = df_2014['Member type']
y_predict = model.predict(X)
print('Accuracy: ',accuracy_score(y, y_predict))
pd.DataFrame(
    confusion_matrix(y, y_predict),
    columns=['Predicted Casual', 'Predicted Member'],
    index=['True Casual', 'True Member']
)
# Out:
# Accuracy:  0.8702863467972337
#              Predicted Casual  Predicted Member
# True Casual               599             44768
# True Member              7263            348492

# %%
df_2014.isna().sum()
# Out:
# Duration                0
# Start station number    0
# End station number      0
# Member type             0
# syear                   0
# smonth                  0
# sday                    0
# shour                   0
# sminute                 0
# eyear                   0
# emonth                  0
# eday                    0
# ehour                   0
# eminute                 0
# dtype: int64

# %%
X = df2.drop('Member type', axis=1)
y = df2['Member type']
model = tree.DecisionTreeClassifier()
model.fit(X,y)
X_test = df_2014.drop(['Member type'],axis = 1)
y_predict = model.predict(X_test)
print('Accuracy: ',accuracy_score(df_2014['Member type'], y_predict))
# Out:
# Accuracy:  0.8574722902259163

# %%
df1.head()
# Out:
#        Duration  Start date  End date  Start station number  \
# Index
# 0          1012      734035    734035                 31208
# 1            61      734035    734035                 31209
# 2          2690      734035    734035                 31600
# 3          1406      734035    734035                 31600
# 4          1413      734035    734035                 31100
#
#        End station number Member type
# Index
# 0                   31108      Member
# 1                   31209      Member
# 2                   31100      Member
# 3                   31602      Member
# 4                   31201      Member

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df3 = scaler.fit_transform(df1.drop(['Member type'],axis = 1))

# %%
df3 = pd.DataFrame(df3)

# %%
df3.head()
# Out:
#           0         1         2         3         4
# 0 -0.069157 -2.545296 -2.545349 -0.401023 -0.930638
# 1 -0.447090 -2.545296 -2.545349 -0.395840 -0.404690
# 2  0.597691 -2.545296 -2.545349  1.630617 -0.972297
# 3  0.087421 -2.545296 -2.545349  1.630617  1.641819
# 4  0.090203 -2.545296 -2.545349 -0.960760 -0.446350

# %%
df3.insert(5, "Member type",list(df1['Member type']), True)

# %%
df3.head()
# Out:
#           0         1         2         3         4 Member type
# 0 -0.069157 -2.545296 -2.545349 -0.401023 -0.930638      Member
# 1 -0.447090 -2.545296 -2.545349 -0.395840 -0.404690      Member
# 2  0.597691 -2.545296 -2.545349  1.630617 -0.972297      Member
# 3  0.087421 -2.545296 -2.545349  1.630617  1.641819      Member
# 4  0.090203 -2.545296 -2.545349 -0.960760 -0.446350      Member

# %%
X = df3.drop('Member type', axis=1)
y = df3['Member type']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
model = tree.DecisionTreeClassifier()
model.fit(X,y)
y_predict = model.predict(X_test)
print('Accuracy: ',accuracy_score(y_test, y_predict))
# Out:
# Accuracy:  0.9996036842465978

# %%
model = ExtraTreesClassifier()
model.fit(X,y)
y_predict = model.predict(X_test)
print('Accuracy: ',accuracy_score(y_test, y_predict))
# Out:
# Accuracy:  0.9996036842465978

# %%
model = RandomForestClassifier()
model.fit(X,y)
y_predict = model.predict(X_test)

print('Accuracy: ',accuracy_score(y_test, y_predict))
# Out:
# Accuracy:  0.9923895456075997

# %%
model = GaussianNB()
model.fit(X,y)
y_predict = model.predict(X_test)

print('Accuracy: ',accuracy_score(y_test, y_predict))
# Out:
# Accuracy:  0.8360444707992765

# %%
model = KNeighborsClassifier()
model.fit(X,y)
y_predict = model.predict(X_test)

print('Accuracy: ',accuracy_score(y_test, y_predict))
# Out:
# Accuracy:  0.8916568084364599

# %%
df3
# Out:
#                 0         1         2         3         4 Member type
# 0       -0.069157 -2.545296 -2.545349 -0.401023 -0.930638      Member
# 1       -0.447090 -2.545296 -2.545349 -0.395840 -0.404690      Member
# 2        0.597691 -2.545296 -2.545349  1.630617 -0.972297      Member
# 3        0.087421 -2.545296 -2.545349  1.630617  1.641819      Member
# 4        0.090203 -2.545296 -2.545349 -0.960760 -0.446350      Member
# 5       -0.081079 -2.545296 -2.545349 -0.914115 -0.451557      Member
# 6       -0.101744 -2.545296 -2.545349 -0.914115 -0.946260      Member
# 7        0.187965 -2.545296 -2.545349 -0.903750 -0.409898      Member
# 8        0.520594 -2.545296 -2.545349  1.630617  1.636611      Member
# 9        0.119611 -2.545296 -2.545349  2.164441  1.647026      Member
# 10      -0.071144 -2.545296 -2.545349  1.112341 -0.451557      Member
# 11      -0.010738 -2.545296 -2.545349  1.646165  1.647026      Member
# ...

# %%
df3['Member type'].value_counts()
# Out:
# Member     1071400
# Casual      270950
# Unknown         14
# Name: Member type, dtype: int64

# %%
df3['Member type'].value_counts()
# Out:
# Member     1071400
# Casual      270950
# Unknown         14
# Name: Member type, dtype: int64

# %%
df3[1].value_counts()
# Out:
#  0.042764    5975
#  0.150975    5847
#  0.493645    5818
# -0.354012    5731
#  0.141958    5475
#  0.006693    5456
#  0.917474    5445
#  0.782209    5353
#  0.908456    5337
#  0.015711    5296
#  0.655962    5270
#  0.087852    5268
# -0.227765    5248
#  0.159993    5245
# -0.236783    5242
# -0.029377    5241
# -0.543382    5214
# -0.002324    5155
#  0.836315    5150
#  0.556769    5148
#  0.971579    5136
# -0.128571    5123
# -0.038395    5114
#  0.466592    5104
#  0.502663    5064
#  0.574804    5059
# -0.101518    5054
#  0.926491    5052
#  0.024728    5052
#  0.132940    5017
#              ...
# -1.760762     669
# -2.401013     663
# -2.410031     624
#  1.097826     619
# -1.003281     616
# -2.139502     589
# -1.039352     582
# -2.446102     578
# -2.328872     573
# -1.950132     553
# -2.500207     539
# -2.491190     537
# -2.428066     505
# -1.391039     500
# -1.382022     424
# -2.464137     422
# -1.796832     420
# -2.473155     411
# -2.527260     377
# ...

# %%
df.head()
# Out:
#        Duration  syear  smonth  sday  shour  sminute  eyear  emonth  eday  \
# Index
# 0          1012   2010       9    20     11       27   2010       9    20
# 1            61   2010       9    20     11       41   2010       9    20
# 2          2690   2010       9    20     12        5   2010       9    20
# 3          1406   2010       9    20     12        6   2010       9    20
# 4          1413   2010       9    20     12       10   2010       9    20
#
#        ehour  eminute  Start station number  End station number Member type
# Index
# 0         11       43                 31208               31108      Member
# 1         11       42                 31209               31209      Member
# 2         12       50                 31600               31100      Member
# 3         12       29                 31600               31602      Member
# 4         12       34                 31100               31201      Member

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021501666240>,
# ...
#       dtype=object)

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (15,20))
ax = fig.gca()
df.hist(ax = ax)
# Out:
# C:\Users\Mohit-PC\Anaconda3F\lib\site-packages\IPython\core\interactiveshell.py:2961: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   exec(code_obj, self.user_global_ns, self.user_ns)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000214DA86CEF0>,
# ...
#       dtype=object)

# %%
import seaborn as sns
corr = df.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
corr = df1.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square = True,
    annot=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
if(df1['Start date'].all() in df1['End date']):
    print('Yes')
else:
    print('No')
# Out:
# Yes

# %%
from sklearn.metrics import mean_squared_error

# %%
model
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
cdf = pd.read_csv('census_data.csv')

# %%
cdf.head()
# Out:
#    73                  Not in universe   0   0.1         High school graduate  \
# 0  58   Self-employed-not incorporated   4    34   Some college but no degree
# 1  18                  Not in universe   0     0                   10th grade
# 2   9                  Not in universe   0     0                     Children
# 3  10                  Not in universe   0     0                     Children
# 4  48                          Private  40    10   Some college but no degree
#
#     0.2  Not in universe.1                           Widowed  \
# 0     0    Not in universe                          Divorced
# 1     0        High school                     Never married
# 2     0    Not in universe                     Never married
# 3     0    Not in universe                     Never married
# 4  1200    Not in universe   Married-civilian spouse present
#
#     Not in universe or children                     Not in universe.2  \
# ...

# %%
cdf.columns = [x for x in range(0,42)]

# %%
cdf.head()
# Out:
#    0                                1   2   3                            4   \
# 0  58   Self-employed-not incorporated   4  34   Some college but no degree
# 1  18                  Not in universe   0   0                   10th grade
# 2   9                  Not in universe   0   0                     Children
# 3  10                  Not in universe   0   0                     Children
# 4  48                          Private  40  10   Some college but no degree
#
#      5                 6                                 7   \
# 0     0   Not in universe                          Divorced
# 1     0       High school                     Never married
# 2     0   Not in universe                     Never married
# 3     0   Not in universe                     Never married
# 4  1200   Not in universe   Married-civilian spouse present
#
#                              8                                     9   \
# 0                  Construction   Precision production craft & repair
# ...

# %%
cdf = pd.read_csv('winequality-red.csv',';')

# %%
cdf.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
cdf.count()
# Out:
# fixed acidity           1599
# volatile acidity        1599
# citric acid             1599
# residual sugar          1599
# chlorides               1599
# free sulfur dioxide     1599
# total sulfur dioxide    1599
# density                 1599
# pH                      1599
# sulphates               1599
# alcohol                 1599
# quality                 1599
# dtype: int64

# %%
cdf.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (15,20))
ax = fig.gca()
cdf.hist(ax = ax)
# Out:
# C:\Users\Mohit-PC\Anaconda3F\lib\site-packages\IPython\core\interactiveshell.py:2961: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   exec(code_obj, self.user_global_ns, self.user_ns)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002152AF20898>,
# ...
#       dtype=object)

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
X = cdf.drop(['quality'],axis = 1)
y = cdf['quality']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
model = LinearRegression()
model.fit(X,y)
y_predict = model.predict(X_test)
print(mean_squared_error(y_test, y_predict))
print(r2_score(y_test, y_predict))
# Out:
# 0.3814438996767282
# 0.35235977812856534

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X,y)
y_predict = model.predict(X_test)
print(mean_squared_error(y_test, y_predict))
print(r2_score(y_test, y_predict))
# Out:
# 0.495
# 0.15955685725200552

# %%
from sklearn.linear_model import BayesianRidge
model = BayesianRidge()
model.fit(X,y)
y_predict = model.predict(X_test)
print(mean_squared_error(y_test, y_predict))
print(r2_score(y_test, y_predict))
# Out:
# 0.3810103984043224
# 0.3530958047381937

# %%
from sklearn.linear_model import ARDRegression
model = ARDRegression()
model.fit(X,y)
y_predict = model.predict(X_test)
print(mean_squared_error(y_test, y_predict))
print(r2_score(y_test, y_predict))
# Out:
# 0.38321914223691145
# 0.34934565603478673
